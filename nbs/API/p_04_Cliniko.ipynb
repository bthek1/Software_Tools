# %% [markdown]
# # Cliniko
#
# > Cliniko
#
# - skip_showdoc: true
# - skip_exec: true

# %% [markdown]
# ## Setup

# %% [markdown]
# ## Dani
#
#
# - Dani cliniko
#   - 2 locations
#   - 100 users - bookkeeper, admin, practitioners
#   - 23 practitioners
#   - 1350 not archieved clients
#   - 168 not archieved, "created_at:>2024-12-07T14:36:23Z" clients
#   - 7434 "starts_at:>2024-10-20T14:15:22Z" appointments
#   - 10003 open cases
#   - 392 open, "starts_at:>2024-10-20T14:15:22Z" cases
#
#
# RM sync
#   - 2 locations
#   - 124 users/practitioners
#   - 3888 appointments
#   - 11585 cases
#   - 6476 clients
#
#
# After reset
#   - 2 locations
#   - 124 users/practitioners
#   - 3890 appointments
#   - 906 cases
#   - 1327 clients
#
# After error fixing
#   - 2 locations
#   - 124 users/practitioners
#   - 3891 appointments created
#   - 127 cases created, 779 updated
#   - 161 clients created, 877 updated

# %%
import base64
import json
import os
from dotenv import load_dotenv
import requests
import pandas as pd
from http import HTTPStatus
import httpx
from datetime import datetime as dt, timedelta, UTC
from typing import Any, Dict, List, Optional, Union

# Load environment variables from the .env file
load_dotenv()
# Out:
# True

# %%
from cliniko_api_client import AuthenticatedClient, Client
from cliniko_api_client.api.business import list_businesses_get
from cliniko_api_client.api.user import list_users_get
from cliniko_api_client.api.practitioner import list_practitioners_get
from cliniko_api_client.api.patient import list_patients_get
from cliniko_api_client.api.individual_appointment import list_individual_appointments_get

from cliniko_api_client.models.attendee_patient import AttendeePatient
from cliniko_api_client.models.practitioner import Practitioner
from cliniko_api_client.types import Response



from cliniko_api_client import errors
from cliniko_api_client.models.list_individual_appointments_get_order import (
    ListIndividualAppointmentsGetOrder,
)
from cliniko_api_client.models.list_individual_appointments_get_response_200 import ListIndividualAppointmentsGetResponse200
from cliniko_api_client.types import UNSET, Response, Unset

# %%
def clinico_client():
    url = os.getenv("CLINIKO_URL")
    key = os.getenv("CLINIKO_KEY")
    vendor_name = os.getenv("CLINIKO_VENDOR_NAME")
    vendor_email = os.getenv("CLINIKO_VENDOR_EMAIL")
    assert url and key and vendor_name and vendor_email, "Please set the environment variables"
    headers = {
        "User-Agent": f"{vendor_name} ({vendor_email})",
    }
    encoded_key = base64.b64encode(f"{key}:".encode()).decode()

    return AuthenticatedClient(base_url=url, token=encoded_key, headers=headers, prefix="Basic")

# %% [markdown]
# ## Get Location List

# %%
now = dt.now(UTC)
now_str = now.strftime("%Y-%m-%dT%H:%M:%SZ")
f"{now_str}"
page=1
per_page=10
sort=[]
# q=[f"updated_at:>{now_str}"]
q = []

# %%
with clinico_client() as client:
    response = list_businesses_get.sync_detailed(
        client=client,
        page = page,
        per_page = per_page,
        sort = sort,
        q = q)
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
        
        # Convert JSON to AttendeePatient objects
        patients_list = [
            AttendeePatient.from_dict(patient) for patient in parsed_content["businesses"]
        ]
        df = pd.DataFrame(parsed_content["businesses"])
    else:
        print(f"Failed to get patients: {response.content}")

# %%
parsed_content.keys()
# Out:
# dict_keys(['businesses', 'total_entries', 'links'])

# %%
parsed_content["links"]
# Out:
# {'self': 'https://api.au4.cliniko.com/v1/businesses?page=1&per_page=10'}

# %%
df
# Out:
#   additional_information additional_invoice_information address_1 address_2  \
# 0                   None                           None      None      None
#
#    appointment_reminders_enabled                        appointment_type_ids  \
# 0                           True  [1599555823732794924, 1599555824135448109]
#
#   archived_at business_name business_registration_name  \
# 0        None      Rmetrics                       None
#
#   business_registration_value  ... post_code show_in_online_bookings state  \
# 0                        None  ...      None                   False  None
#
#   time_zone time_zone_identifier            updated_at website_address  \
# 0  Brisbane   Australia/Brisbane  2025-01-21T12:02:34Z            None
#
#                                        practitioners  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                         appointments  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                                links
# 0  {'self': 'https://api.au4.cliniko.com/v1/busin...
#
# [1 rows x 30 columns]

# %% [markdown]
# ## Get User List

# %%
now = dt.now(UTC)
now_str = now.strftime("%Y-%m-%dT%H:%M:%SZ")
f"{now_str}"
# Out:
# '2025-05-19T04:33:45Z'

# %%
page=1
per_page=75
sort=[]
# q=[f"updated_at:>{now_str}"]
q = []

# %%
with clinico_client() as client:
    response = list_users_get.sync_detailed(
        client=client,
        page = page,
        per_page = per_page,
        sort = sort,
        q = q)
    
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
        
        # Convert JSON to AttendeePatient objects
        patients_list = [
            AttendeePatient.from_dict(users) for users in parsed_content["users"]
        ]
        df = pd.DataFrame(parsed_content["users"])
    
df
# Out:
#    active            created_at                 email    first_name  \
# 0    True  2025-01-15T23:11:53Z   bthekkel1@gmail.com           Ben
# 1   False  2025-01-15T23:41:43Z  habena4271@fenxz.com  Practitioner
# 2    True  2025-02-13T06:34:47Z     kiera@cfih.com.au         Kiera
#
#                     id   last_name  \
# 0  1599555821232989634     Thekkel
# 1  1599570836774200775  the Forth1
# 2  1620072466984478424    Buchanan
#
#                                        phone_numbers           role time_zone  \
# 0  [{'normalized_number': '61415051025', 'number'...  administrator  Brisbane
# 1                                                 []   practitioner  Brisbane
# 2                                                 []  administrator  Brisbane
#
#   time_zone_identifier title            updated_at  user_active  \
# 0   Australia/Brisbane  None  2025-05-19T00:34:21Z         True
# 1   Australia/Brisbane    Mr  2025-02-17T03:45:04Z        False
# 2   Australia/Brisbane  None  2025-02-15T02:32:01Z         True
#
#                                                links
# 0  {'self': 'https://api.au4.cliniko.com/v1/users...
# 1  {'self': 'https://api.au4.cliniko.com/v1/users...
# 2  {'self': 'https://api.au4.cliniko.com/v1/users...

# %%
with clinico_client() as client:
    response = list_users_get.sync_detailed(client=client)
    if response.status_code == 200:
        parsed_content = json.loads(response.content)

parsed_content["users"]
# Out:
# [{'active': True,
#   'created_at': '2025-01-15T23:11:53Z',
#   'email': 'bthekkel1@gmail.com',
#   'first_name': 'Ben',
#   'id': '1599555821232989634',
#   'last_name': 'Thekkel',
#   'phone_numbers': [{'normalized_number': '61415051025',
#     'number': '0415051025',
#     'phone_type': 'Mobile'}],
#   'role': 'administrator',
#   'time_zone': 'Brisbane',
#   'time_zone_identifier': 'Australia/Brisbane',
#   'title': None,
#   'updated_at': '2025-03-11T03:56:15Z',
#   'user_active': True,
#   'links': {'self': 'https://api.au4.cliniko.com/v1/users/1599555821232989634'}},
#  {'active': False,
#   'created_at': '2025-01-15T23:41:43Z',
#   'email': 'habena4271@fenxz.com',
#   'first_name': 'Practitioner',
#   'id': '1599570836774200775',
#   'last_name': 'the Forth1',
#   'phone_numbers': [],
#   'role': 'practitioner',
#   'time_zone': 'Brisbane',
#   'time_zone_identifier': 'Australia/Brisbane',
#   'title': 'Mr',
#   'updated_at': '2025-02-17T03:45:04Z',
#   'user_active': False,
#   'links': {'self': 'https://api.au4.cliniko.com/v1/users/1599570836774200775'}},
#  {'active': True,
#   'created_at': '2025-02-13T06:34:47Z',
#   'email': 'kiera@cfih.com.au',
#   'first_name': 'Kiera',
#   'id': '1620072466984478424',
#   'last_name': 'Buchanan',
#   'phone_numbers': [],
#   'role': 'administrator',
#   'time_zone': 'Brisbane',
#   'time_zone_identifier': 'Australia/Brisbane',
#   'title': None,
#   'updated_at': '2025-02-15T02:32:01Z',
#   'user_active': True,
#   'links': {'self': 'https://api.au4.cliniko.com/v1/users/1620072466984478424'}}]

# %% [markdown]
# ## Get Practitioner List

# %%
now = dt.now(UTC)
now_str = now.strftime("%Y-%m-%dT%H:%M:%SZ")
f"{now_str}"
# Out:
# '2025-03-11T04:19:47Z'

# %%
page=1
per_page=90
sort=[]
# q=[f"updated_at:>{now_str}"]
q = [ ]

# %%
with clinico_client() as client:
    response = list_practitioners_get.sync(client=client)
response.practitioners[1]
# Out:
# Practitioner(active=True, appointment_types=PractitionerAppointmentTypes(links=PractitionerAppointmentTypesLinks(self_='https://api.au4.cliniko.com/v1/practitioners/1620072773260945370/appointment_types', additional_properties={}), additional_properties={}), appointments=PractitionerAppointments(links=PractitionerAppointmentsLinks(self_='https://api.au4.cliniko.com/v1/practitioners/1620072773260945370/appointments', additional_properties={}), additional_properties={}), created_at=datetime.datetime(2025, 2, 13, 6, 35, 24, tzinfo=tzutc()), default_appointment_type=<cliniko_api_client.types.Unset object>, description=None, designation=None, display_name='Kiera', first_name='Kiera', id='1620072773260945370', invoices=PractitionerInvoices(links=PractitionerInvoicesLinks(self_='https://api.au4.cliniko.com/v1/practitioners/1620072773260945370/invoices', additional_properties={}), additional_properties={}), label='Kiera Buchanan', last_name='Buchanan', links=PractitionerLinks(self_='https://api.au4.cliniko.com/v1/practitioners/1620072773260945370', additional_properties={}), practitioner_reference_numbers=PractitionerPractitionerReferenceNumbers(links=PractitionerPractitionerReferenceNumbersLinks(self_='https://api.au4.cliniko.com/v1/practitioners/1620072773260945370/practitioner_reference_numbers', additional_properties={}), additional_properties={}), show_in_online_bookings=True, title=None, updated_at=datetime.datetime(2025, 2, 17, 3, 12, 25, tzinfo=tzutc()), user=PractitionerUser(links=PractitionerUserLinks(self_='https://api.au4.cliniko.com/v1/users/1620072466984478424', additional_properties={}), additional_properties={}), additional_properties={})

# %%
with clinico_client() as client:
    response = list_practitioners_get.sync_detailed(
        client=client,
        page = page,
        per_page = per_page,
        sort = sort,
        q = q)
    
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
        
        # Convert JSON to AttendeePatient objects
        patients_list = [
            AttendeePatient.from_dict(patient) for patient in parsed_content["practitioners"]
        ]
        df = pd.DataFrame(parsed_content["practitioners"])

df
# Out:
#    active            created_at description designation display_name  \
# 0    True  2025-01-15T23:11:53Z        None        None          Ben
# 1    True  2025-02-13T06:35:24Z        None        None        Kiera
#
#   first_name                   id           label last_name  \
# 0        Ben  1599555821358819229     Ben Thekkel   Thekkel
# 1      Kiera  1620072773260945370  Kiera Buchanan  Buchanan
#
#    show_in_online_bookings title            updated_at  \
# 0                     True  None  2025-02-24T01:12:57Z
# 1                     True  None  2025-02-17T03:12:25Z
#
#                                                 user  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                         appointments  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                    appointment_types  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                             invoices  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                       practitioner_reference_numbers  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                                links
# 0  {'self': 'https://api.au4.cliniko.com/v1/pract...
# 1  {'self': 'https://api.au4.cliniko.com/v1/pract...

# %%
with clinico_client() as client:
    response = list_practitioners_get.sync_detailed(client=client)
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
len(parsed_content["practitioners"])
# Out:
# 2

# %%
import re
for practitioner in parsed_content["practitioners"]:
    user_self_url = practitioner["user"]["links"]["self"]
    # Extract the user ID from the URL
    user_id = re.search(r'/users/(\d+)', user_self_url).group(1)
    print(f"Practitioner Name: {practitioner['display_name']}, User ID: {user_id}")
# Out:
# Practitioner Name: Ben, User ID: 1599555821232989634
# Practitioner Name: Kiera, User ID: 1620072466984478424

# %% [markdown]
# ## Create Patients

# %%
import json
from faker import Faker

# Initialize Faker
faker = Faker()

def generate_random_patient():
    """Generate a random patient dictionary."""
    return {
        "first_name": faker.first_name(),
        "last_name": faker.last_name(),
        "email": faker.email(),
        "sex": faker.random.choice(["Male", "Female", "Other"]),
        "date_of_birth": faker.date_of_birth(minimum_age=18, maximum_age=90).strftime("%Y-%m-%d"),
        "patient_phone_numbers": [
            {
                "normalized_number": faker.msisdn(),
                "number": faker.phone_number(),
                "phone_type": faker.random.choice(["Mobile", "Home", "Work"])
            },
            {
                "normalized_number": faker.msisdn(),
                "number": faker.phone_number(),
                "phone_type": faker.random.choice(["Mobile", "Home", "Work"])
            }
        ]
    }


# generate_random_patient()

# %%
new_patient = {
        "first_name": "John",
        "last_name": "Doe",
        "email": "ohndoe@example.com",
        "sex": "Male",
        "date_of_birth": "2001-08-24",
        'patient_phone_numbers': [
            {'normalizd_number': '614151025',
             'number': '0415051025',
             'phone_type': 'Mobile'},
            {'normalized_number': '61123412341234',
             'number': '123412341234',
             'phone_type': 'Mobile'}],
    }
# no "create_patient_post" method? Need to create manual like this:
# response: Response[Patient] = create_patient_post.sync_detailed(client=client, body=new_patient)
def create_client(new_patient):
    with clinico_client() as client:
        res = client.get_httpx_client().post(
            url=f"{client._base_url}/patients",
            headers=client._headers,
            json=new_patient,
        )
        raw_objects = json.loads(res.content)
        print(res.status_code)
        print(res.json())
    return raw_objects

# %%
# raw_objects = create_client(new_patient)
# raw_objects

# %%
# result = []
# for i in range(20):
#     new_patient = generate_random_patient()
#     # print(new_patient)
#     result.append(create_client(new_patient))

# %% [markdown]
# ## Edit Patient

# %%
def edit_client(new_patient, id):
    with clinico_client() as client:
        res = client.get_httpx_client().patch(
            url=f"{client._base_url}/patients/{id}",
            headers=client._headers,
            json=new_patient,
        )
        raw_objects = json.loads(res.content)
        print(res.status_code)
    return raw_objects

# %%
# edit_patient = {
#         "first_name": "Name",
#         "last_name": "Change",
#         "email": "ohndoe@example.com",
#         'patient_phone_numbers': [
#             {'normalizd_number': '614151025',
#              'number': '0415051025',
#              'phone_type': 'Mobile'},
#             {'normalized_number': '61123412341234',
#              'number': '123412341234',
#              'phone_type': 'Mobile'}],
#                                         }
# # edit_client(edit_patient, 1569618156094235685)

# %% [markdown]
# ## Get Patient List

# %%
now = dt.now(UTC)
now_str = now.strftime("%Y-%m-%dT%H:%M:%SZ")
f"{now_str}"
# Out:
# '2025-03-11T04:19:58Z'

# %%
page=1
per_page=100
sort=[]
# q=[f"updated_at:>{now_str}", "archived_at:*"]
q=[ ]

# %%
with clinico_client() as client:
    response = list_patients_get.sync_detailed(
        client=client,
        page=page,
        per_page=per_page,
        sort=sort,
        q=q,
    )
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
        data = parsed_content["patients"]
        # Convert JSON to AttendeePatient objects
        patients_list = [
            AttendeePatient.from_dict(patient) for patient in data
        ]
        df = pd.DataFrame(data)

# df[[ "updated_at", "id", "first_name", "last_name", "patient_phone_numbers", "sex", "created_at", "archived_at"]][1:5]
df[["id", "first_name", "last_name", "sex", "created_at", 'gender', 'gender_identity', 'pronouns']][1:]

# df
# Out:
#                      id   first_name  last_name     sex            created_at  \
# 1   1599572253912082110         John        Doe    Male  2025-01-15T23:44:31Z
# 2   1599573978425337541     Danielle   Thompson  Female  2025-01-15T23:47:57Z
# 3   1599573980203722438     Kristina   Marshall    Male  2025-01-15T23:47:57Z
# 4   1599573981269075655     Jennifer    Hammond    Male  2025-01-15T23:47:57Z
# 5   1599573983525611208       Taylor  Rodriguez   Other  2025-01-15T23:47:58Z
# 6   1599573985060726473     Danielle      Nixon   Other  2025-01-15T23:47:58Z
# 7   1599573987107546826      Michael   Williams  Female  2025-01-15T23:47:58Z
# 8   1599573989104035531       Andrea   Ferguson  Female  2025-01-15T23:47:58Z
# 9   1599573990169388748       Judith      Moran   Other  2025-01-15T23:47:58Z
# 10  1599573991167633101        Jorge     Martin    Male  2025-01-15T23:47:59Z
# 11  1599573992308483790        April      Meyer   Other  2025-01-15T23:47:59Z
# 12  1599573993440945871      Rachael   Franklin   Other  2025-01-15T23:47:59Z
# 13  1599573994523076304        David     Barker    Male  2025-01-15T23:47:59Z
# 14  1599573996234352337       Lauren   Mcdonald  Female  2025-01-15T23:47:59Z
# 15  1599573997425534674      Michael     Wagner  Female  2025-01-15T23:47:59Z
# 16  1599573998541219539    Stephanie     Mendez    Male  2025-01-15T23:47:59Z
# 17  1599573999631738580       Dakota     Hurley  Female  2025-01-15T23:48:00Z
# 18  1599574000713869013       Connie      Nunez    Male  2025-01-15T23:48:00Z
# 19  1599574001686947542  Christopher   Mitchell  Female  2025-01-15T23:48:00Z
# 20  1599574002811021015      Stephen    Mullins   Other  2025-01-15T23:48:00Z
# 21  1599574003876374232        James      Young    Male  2025-01-15T23:48:00Z
# 22  1621400360604149675        Monte      Burns          2025-02-15T02:33:05Z
# 23  1621678737441432956        Peter  Geoffries          2025-02-15T11:46:10Z
# 24  1621681854195180928        Sarah    Winston    None  2025-02-15T11:52:21Z
#
#    gender gender_identity                                           pronouns
# 1    None            None                                               None
# 2    None            None                                               None
# 3    None            None                                               None
# 4    None            None                                               None
# 5    None            None                                               None
# 6    None            None                                               None
# 7    None            None                                               None
# 8    None       Androgyne  {'reflexive': 'zirself', 'accusative': 'him', ...
# 9    None            None                                               None
# 10   None            None                                               None
# 11   None                                                               None
# 12   None            None                                               None
# 13   None            None                                               None
# 14   None            None                                               None
# 15   None                                                               None
# 16   None            None                                               None
# 17   None            None                                               None
# 18   None                                                               None
# 19   None            None                                               None
# 20   None            None                                               None
# 21   None            None                                               None
# 22   None                                                               None
# 23   None                                                               None
# 24   None            None                                               None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 54 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   accepted_email_marketing      25 non-null     bool
#  1   accepted_privacy_policy       0 non-null      object
#  2   accepted_sms_marketing        25 non-null     bool
#  3   address_1                     6 non-null      object
#  4   address_2                     6 non-null      object
#  5   address_3                     6 non-null      object
#  6   appointment_notes             6 non-null      object
#  7   archived_at                   0 non-null      object
#  8   city                          6 non-null      object
#  9   country                       25 non-null     object
#  10  country_code                  25 non-null     object
#  11  created_at                    25 non-null     object
#  12  custom_fields                 0 non-null      object
#  13  date_of_birth                 25 non-null     object
#  14  deleted_at                    0 non-null      object
#  15  dva_card_number               6 non-null      object
#  16  email                         22 non-null     object
#  17  emergency_contact             6 non-null      object
#  18  first_name                    25 non-null     object
#  19  gender                        0 non-null      object
#  20  gender_identity               6 non-null      object
#  21  id                            25 non-null     object
#  22  invoice_default_to            6 non-null      object
#  23  invoice_email                 0 non-null      object
#  24  invoice_extra_information     6 non-null      object
#  25  label                         25 non-null     object
#  26  last_name                     25 non-null     object
#  27  medicare                      6 non-null      object
#  28  medicare_reference_number     6 non-null      object
#  29  merged_at                     0 non-null      object
#  30  notes                         6 non-null      object
#  31  occupation                    6 non-null      object
#  32  old_reference_id              6 non-null      object
#  33  patient_phone_numbers         25 non-null     object
#  34  post_code                     6 non-null      object
#  35  preferred_first_name          1 non-null      object
#  36  pronouns                      1 non-null      object
#  37  receives_cancellation_emails  25 non-null     bool
#  38  receives_confirmation_emails  25 non-null     bool
#  39  referral_source               0 non-null      object
#  40  reminder_type                 25 non-null     object
#  41  sex                           24 non-null     object
#  42  state                         6 non-null      object
#  43  time_zone                     0 non-null      object
#  44  title                         7 non-null      object
#  45  updated_at                    25 non-null     object
#  46  appointments                  25 non-null     object
#  47  attendees                     25 non-null     object
#  48  invoices                      25 non-null     object
#  49  patient_attachments           25 non-null     object
#  50  medical_alerts                25 non-null     object
#  51  relationships                 25 non-null     object
#  52  links                         25 non-null     object
#  53  latest_booking                10 non-null     object
# dtypes: bool(4), object(50)
# memory usage: 10.0+ KB

# %%
for patient in data:
    print(f"Patient ID: {patient['id']} updated at: {type(patient.get('updated_at', 'N/A'))}")

# %%
# for patient in data:
#     # Mobile, Home, Work, Fax, Other
#     print(f"\n {patient["first_name"]}")
#     if "patient_phone_numbers" in patient and isinstance(patient["patient_phone_numbers"], list):
#         for phone in patient["patient_phone_numbers"]:
#             # Ensure each phone entry has the required fields
#             number = phone.get("normalized_number", "")
#             type = phone.get("phone_type", "")
#             print(f"{number=} , {type=}")

# %%
# Define the parameters for the API call
page = 1  # Specify the page number
per_page = 100  # Specify the number of results per page
sort = ["last_name:desc"]  # Sort by the "last_name" field
q = ["created_at:>2024-12-07T14:36:23Z"]  # Query filter (example for email)

# %%
with clinico_client() as client:
    response = list_patients_get.sync_detailed(
        client=client,
        page=page,
        per_page=per_page,
        sort=sort,
        q=q,
    )
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
        
        # Convert JSON to AttendeePatient objects
        patients_list = [
            AttendeePatient.from_dict(patient) for patient in parsed_content["patients"]
        ]
        df = pd.DataFrame(parsed_content["patients"])

# df[['address_1', 'address_2', 'address_3',
#        'appointment_notes', 'archived_at', 'city', 'country', 'country_code',
#        'created_at', 'custom_fields', 'date_of_birth', 'deleted_at',
#        'dva_card_number', 'email', 'emergency_contact', 'first_name', 'gender',
#        'gender_identity', 'id', 'label', 'last_name', 'medicare',
#        'medicare_reference_number', 'merged_at', 'notes', 'occupation',
#        'old_reference_id', 'patient_phone_numbers', 'post_code',
#        'preferred_first_name', 'pronouns',
#        'sex', 'state', 'time_zone', 'title', 'updated_at']]

df[['first_name', 'last_name', 'email','id']]
# Out:
#      first_name  last_name                            email  \
# 0         Donot     Delete               ohndoe@example.com
# 1          John        Doe               ohndoe@example.com
# 2      Danielle   Thompson       bennettstanley@example.com
# 3      Kristina   Marshall            wgonzalez@example.net
# 4      Jennifer    Hammond              david91@example.com
# 5        Taylor  Rodriguez              jenna72@example.com
# 6      Danielle      Nixon            melissa53@example.org
# 7       Michael   Williams         davidcamacho@example.org
# 8        Andrea   Ferguson              kevin34@example.com
# 9        Judith      Moran        gregoryashley@example.com
# 10        Jorge     Martin              aberger@example.net
# 11        April      Meyer               dperez@example.com
# 12      Rachael   Franklin             alancole@example.net
# 13        David     Barker  christophermcdaniel@example.net
# 14       Lauren   Mcdonald              julia08@example.com
# 15      Michael     Wagner          justingreer@example.org
# 16    Stephanie     Mendez     chelseaalexander@example.net
# 17       Dakota     Hurley               todd46@example.org
# 18       Connie      Nunez        monroecarolyn@example.com
# 19  Christopher   Mitchell               uwells@example.org
# 20      Stephen    Mullins               seth40@example.org
# 21        James      Young              dprince@example.net
#
#                      id
# 0   1599564573638141606
# 1   1599572253912082110
# 2   1599573978425337541
# 3   1599573980203722438
# 4   1599573981269075655
# 5   1599573983525611208
# 6   1599573985060726473
# 7   1599573987107546826
# 8   1599573989104035531
# 9   1599573990169388748
# 10  1599573991167633101
# 11  1599573992308483790
# 12  1599573993440945871
# 13  1599573994523076304
# 14  1599573996234352337
# 15  1599573997425534674
# 16  1599573998541219539
# 17  1599573999631738580
# 18  1599574000713869013
# 19  1599574001686947542
# 20  1599574002811021015
# 21  1599574003876374232

# %%
def fetch_patients(page = 1, per_page = 10, sort = [], q = []):
    
    next = True
    with clinico_client() as client:
        while next:
            response = list_patients_get.sync_detailed(
                client=client,
                page=page,
                per_page=per_page,
                sort=sort,
                q=q,
            )
            if response.status_code == 200:
                parsed_content = json.loads(response.content)
                
                # Convert JSON to AttendeePatient objects
                patients_list = [
                    AttendeePatient.from_dict(patient) for patient in parsed_content["patients"]
                ]
                df = pd.DataFrame(parsed_content["patients"])
                links = parsed_content["links"]
                next = links.get("next", None) is not None
                page += 1
                print(links)
fetch_patients()
# Out:
# {'self': 'https://api.au4.cliniko.com/v1/patients?page=1&per_page=10', 'next': 'https://api.au4.cliniko.com/v1/patients?page=2&per_page=10'}
# {'self': 'https://api.au4.cliniko.com/v1/patients?page=2&per_page=10', 'next': 'https://api.au4.cliniko.com/v1/patients?page=3&per_page=10', 'previous': 'https://api.au4.cliniko.com/v1/patients?page=1&per_page=10'}
# {'self': 'https://api.au4.cliniko.com/v1/patients?page=3&per_page=10', 'previous': 'https://api.au4.cliniko.com/v1/patients?page=2&per_page=10'}

# %%
df.columns
# Out:
# Index(['accepted_email_marketing', 'accepted_privacy_policy',
#        'accepted_sms_marketing', 'address_1', 'address_2', 'address_3',
#        'appointment_notes', 'archived_at', 'city', 'country', 'country_code',
#        'created_at', 'custom_fields', 'date_of_birth', 'deleted_at',
#        'dva_card_number', 'email', 'emergency_contact', 'first_name', 'gender',
#        'gender_identity', 'id', 'invoice_default_to', 'invoice_email',
#        'invoice_extra_information', 'label', 'last_name', 'medicare',
#        'medicare_reference_number', 'merged_at', 'notes', 'occupation',
#        'old_reference_id', 'patient_phone_numbers', 'post_code',
#        'preferred_first_name', 'pronouns', 'receives_cancellation_emails',
#        'receives_confirmation_emails', 'referral_source', 'reminder_type',
#        'sex', 'state', 'time_zone', 'title', 'updated_at', 'appointments',
#        'attendees', 'invoices', 'patient_attachments', 'medical_alerts',
#        'relationships', 'links', 'latest_booking'],
#       dtype='object')

# %%
patients_list[0]['email']
# Out:
# 'dprince@example.net'

# %%
parsed_content["patients"][0]['email']
# Out:
# 'dprince@example.net'

# %% [markdown]
# ## Get Appointment List

# %%
from crms.cliniko.api_base import UniversalClinikoAPI

# %%
def extract_id_from_link(data):
    """
    Extracts the ID from the 'self' link for the given key.
    
    Args:
        data (dict): The parent dictionary containing the link information.
        key (str): The key for the dictionary to access the link.
    
    Returns:
        str: The extracted ID.
    """
    link = data.get("links", {}).get("self")
    return link.split("/")[-1] if link else None

# %%
now = dt.now(UTC)
now_str = now.strftime("%Y-%m-%dT%H:%M:%SZ")
f"{now_str}"
# Out:
# '2025-02-06T02:33:24Z'

# %%
page=1
per_page=100
sort=[]
# q=[f"updated_at:>{now_str}", "archived_at:*", "cancelled_at:*", "archived_at:*", "cancelled_at:*"]
q = ["archived_at:*", "cancelled_at:*", "starts_at:>2024-10-20T14:15:22Z"]

# %%
with clinico_client() as client:
    response = UniversalClinikoAPI.sync_detailed(
        client=client, 
        q = q,
        page = page,
        per_page = per_page,
        sort = sort,
        method="get",
        url="/individual_appointments")
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
    else:
        print(f"Failed to get patients: {response.content}")

# %%
data = parsed_content["individual_appointments"]
# Convert JSON to AttendeePatient objects
patients_list = [
    AttendeePatient.from_dict(patient) for patient in data
]
df = pd.DataFrame(data)
df
# Out:
#   archived_at booking_ip_address cancellation_note cancellation_reason  \
# 0        None               None              None                None
# 1        None               None              None                None
# 2        None               None              None                None
# 3        None               None              None                None
# 4        None               None              None                None
# 5        None               None              None                None
# 6        None               None              None                None
# 7        None               None              None                None
#
#   cancellation_reason_description cancelled_at  \
# 0                                         None
# 1                                         None
# 2                                         None
# 3                                         None
# 4                                         None
# 5                                         None
# 6                                         None
# 7                                         None
#
#                                            conflicts            created_at  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...  2025-01-15T23:50:47Z
# 1  {'links': {'self': 'https://api.au4.cliniko.co...  2025-01-15T23:51:29Z
# 2  {'links': {'self': 'https://api.au4.cliniko.co...  2025-01-15T23:52:14Z
# 3  {'links': {'self': 'https://api.au4.cliniko.co...  2025-01-15T23:52:26Z
# 4  {'links': {'self': 'https://api.au4.cliniko.co...  2025-01-15T23:52:46Z
# 5  {'links': {'self': 'https://api.au4.cliniko.co...  2025-01-15T23:53:13Z
# 6  {'links': {'self': 'https://api.au4.cliniko.co...  2025-01-16T02:19:15Z
# 7  {'links': {'self': 'https://api.au4.cliniko.co...  2025-01-16T02:20:22Z
#
#   deleted_at  did_not_arrive  ...  \
# 0       None           False  ...
# 1       None           False  ...
# 2       None           False  ...
# 3       None           False  ...
# 4       None           False  ...
# 5       None           False  ...
# 6       None           False  ...
# 7       None           False  ...
#
#                                       telehealth_url treatment_note_status  \
# 0  https://rmetrics.au4.cliniko.com/appointments/...                  None
# 1  https://rmetrics.au4.cliniko.com/appointments/...                  None
# 2  https://rmetrics.au4.cliniko.com/appointments/...                  None
# 3  https://rmetrics.au4.cliniko.com/appointments/...                  None
# 4  https://rmetrics.au4.cliniko.com/appointments/...                  None
# 5  https://rmetrics.au4.cliniko.com/appointments/...                  None
# 6  https://rmetrics.au4.cliniko.com/appointments/...                  None
# 7  https://rmetrics.au4.cliniko.com/appointments/...                  None
#
#              updated_at                                   appointment_type  \
# 0  2025-01-15T23:50:48Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  2025-01-15T23:51:29Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  2025-01-15T23:52:14Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 3  2025-01-15T23:52:26Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 4  2025-01-15T23:52:46Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 5  2025-01-15T23:53:13Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 6  2025-01-21T13:21:10Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 7  2025-01-16T02:20:22Z  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                             business  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
# 3  {'links': {'self': 'https://api.au4.cliniko.co...
# 4  {'links': {'self': 'https://api.au4.cliniko.co...
# 5  {'links': {'self': 'https://api.au4.cliniko.co...
# 6  {'links': {'self': 'https://api.au4.cliniko.co...
# 7  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                         practitioner  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
# 3  {'links': {'self': 'https://api.au4.cliniko.co...
# 4  {'links': {'self': 'https://api.au4.cliniko.co...
# 5  {'links': {'self': 'https://api.au4.cliniko.co...
# 6  {'links': {'self': 'https://api.au4.cliniko.co...
# 7  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                              patient  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
# 3  {'links': {'self': 'https://api.au4.cliniko.co...
# 4  {'links': {'self': 'https://api.au4.cliniko.co...
# 5  {'links': {'self': 'https://api.au4.cliniko.co...
# 6  {'links': {'self': 'https://api.au4.cliniko.co...
# 7  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                            attendees  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
# 3  {'links': {'self': 'https://api.au4.cliniko.co...
# 4  {'links': {'self': 'https://api.au4.cliniko.co...
# 5  {'links': {'self': 'https://api.au4.cliniko.co...
# 6  {'links': {'self': 'https://api.au4.cliniko.co...
# 7  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                                links  \
# 0  {'self': 'https://api.au4.cliniko.com/v1/indiv...
# 1  {'self': 'https://api.au4.cliniko.com/v1/indiv...
# 2  {'self': 'https://api.au4.cliniko.com/v1/indiv...
# 3  {'self': 'https://api.au4.cliniko.com/v1/indiv...
# 4  {'self': 'https://api.au4.cliniko.com/v1/indiv...
# 5  {'self': 'https://api.au4.cliniko.com/v1/indiv...
# 6  {'self': 'https://api.au4.cliniko.com/v1/indiv...
# 7  {'self': 'https://api.au4.cliniko.com/v1/indiv...
#
#                                         patient_case
# 0                                                NaN
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6  {'links': {'self': 'https://api.au4.cliniko.co...
# 7  {'links': {'self': 'https://api.au4.cliniko.co...
#
# [8 rows x 33 columns]

# %%
# for appointment in df[["appointment_type"]]:
#     print(appointment[:])

# parsed_content.keys()
for appointment in data:
    business_id = extract_id_from_link(appointment.get("business", {}))
    practitioner_id = extract_id_from_link(appointment.get("practitioner", {}))
    patient_id = extract_id_from_link(appointment.get("patient", {}))

    print(f"Business ID: {business_id}, Practitioner ID: {practitioner_id}, Patient ID: {patient_id}")
# Out:
# Business ID: 1599555824487770101, Practitioner ID: 1599555821358819229, Patient ID: 1599573994523076304
# Business ID: 1599555824487770101, Practitioner ID: 1599555821358819229, Patient ID: 1599573997425534674
# Business ID: 1599555824487770101, Practitioner ID: 1599555821358819229, Patient ID: 1599573992308483790
# Business ID: 1599555824487770101, Practitioner ID: 1599570839030736801, Patient ID: 1599574001686947542
# Business ID: 1599555824487770101, Practitioner ID: 1599570839030736801, Patient ID: 1599573990169388748
# Business ID: 1599555824487770101, Practitioner ID: 1599570839030736801, Patient ID: 1599573990169388748
# Business ID: 1599555824487770101, Practitioner ID: 1599570839030736801, Patient ID: 1599573989104035531
# Business ID: 1599555824487770101, Practitioner ID: 1599570839030736801, Patient ID: 1599573989104035531

# %%
page = 1 
per_page = 100
sort = []
q = ["cancelled_at:*", "deleted_at:*", "conflicts:*"]

with clinico_client() as client:
    response = UniversalClinikoAPI.sync_detailed(
        client=client,
        page=page,
        per_page=per_page,
        sort=sort,
        q=q,
        method="get",
        url="/individual_appointments",
    )
    if response.status_code == 200:
        parsed_content = json.loads(response.content)

    data = parsed_content["individual_appointments"]
    # # Convert JSON to AttendeePatient objects
    df = pd.DataFrame(data)


# data[0].keys()
df.keys()
# df[["deleted_at", "did_not_arrive", "cancellation_note", "cancellation_reason", 
#     "cancellation_reason_description", "cancelled_at", "conflicts", "created_at", 
#     "patient_arrived", "starts_at", "updated_at"]]

# deleted_at, did_not_arrive, cancellation_note, cancellation_reason, 
# cancellation_reason_description, cancelled_at, conflicts, created_at, patient_arrived, starts_at, updated_at
# Out:
# Index(['archived_at', 'booking_ip_address', 'cancellation_note',
#        'cancellation_reason', 'cancellation_reason_description',
#        'cancelled_at', 'conflicts', 'created_at', 'deleted_at',
#        'did_not_arrive', 'email_reminder_sent', 'ends_at',
#        'has_patient_appointment_notes', 'id', 'invoice_status', 'notes',
#        'online_booking_policy_accepted', 'patient_arrived', 'patient_name',
#        'repeat_rule', 'repeats', 'sms_reminder_sent', 'starts_at',
#        'telehealth_url', 'treatment_note_status', 'updated_at',
#        'appointment_type', 'business', 'practitioner', 'patient', 'attendees',
#        'links', 'patient_case'],
#       dtype='object')

# %%
for data_row in data:
    print(data_row["business"])
# Out:
# {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}}
# {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}}
# {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}}
# {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}}
# {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}}
# {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}}
# {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}}
# {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}}

# %% [markdown]
# ## Get Cases List

# %%
now = dt.now(UTC)
now_str = now.strftime("%Y-%m-%dT%H:%M:%SZ")
f"{now_str}"
# Out:
# '2025-02-06T02:33:27Z'

# %%
page=1
per_page=100
sort=[]
# q=[f"updated_at:>{now_str}"]
# q = ["closed_at:!?", "created_at:>2024-12-07T14:36:23Z"]
q = []

# %%
def extract_id(data):
    """
    Extracts the ID from the 'self' link for the given key.
    
    Args:
        data (dict): The parent dictionary containing the link information.
        key (str): The key for the dictionary to access the link.
    
    Returns:
        str: The extracted ID.
    """
    link = data.get("links", {}).get("self")
    return link.split("/")[-1] if link else None

# %%
with clinico_client() as client:
    response = UniversalClinikoAPI.sync_detailed(
        client=client,
        page=page,
        per_page=per_page,
        sort=sort,
        q=q,
        method="get",
        url="/patient_cases",
    )
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
        cases = parsed_content["patient_cases"]
        df = pd.DataFrame(cases)
    else:
        print(f"Failed to get patients: {response.content}")

df
# cases
# Out:
#   archived_at                                attendee_ids  closed closed_at  \
# 0        None                       [1599575758437623401]   False      None
# 1        None                       [1599576137376212596]   False      None
# 2        None  [1599650128153552365, 1599650688755836403]   False      None
#
#              created_at expiry_date                   id  \
# 0  2025-01-15T23:51:29Z        None  1599575756776678510
# 1  2025-01-15T23:52:14Z        None  1599576134842852464
# 2  2025-01-16T01:58:15Z        None  1599639556703921319
#
#   include_cancelled_attendees include_dna_attendees issue_date  ...  \
# 0                        None                  None       None  ...
# 1                        None                  None       None  ...
# 2                        None                  None       None  ...
#
#                                                notes  referral referral_type  \
# 0                              case notes more\nmore     False          None
# 1  case  notes for test case with 10 max appointm...     False          None
# 2        new case for Andrea Ferguson\n\nadded notes     False          None
#
#              updated_at                                            patient  \
# 0  2025-01-21T13:22:42Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  2025-01-15T23:52:14Z  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  2025-01-16T06:36:52Z  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                            attendees  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                             bookings  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                  patient_attachments  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                             invoices  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                                links
# 0  {'self': 'https://api.au4.cliniko.com/v1/patie...
# 1  {'self': 'https://api.au4.cliniko.com/v1/patie...
# 2  {'self': 'https://api.au4.cliniko.com/v1/patie...
#
# [3 rows x 23 columns]

# %% [markdown]
# ## Get File
#
#
# > Get files for client for cliniko

# %%
page=1
per_page=100
sort=[]
# q=[f"updated_at:>{now_str}"]
# q = ["closed_at:!?", "created_at:>2024-12-07T14:36:23Z"]
q = []

# %%
with clinico_client() as client:
    response = UniversalClinikoAPI.sync_detailed(
        client=client,
        page=page,
        per_page=per_page,
        sort=sort,
        q=q,
        method="get",
        url="/patient_attachments",
    )
    if response.status_code == 200:
        parsed_content = json.loads(response.content)
        cases = parsed_content["patient_attachments"]
        df = pd.DataFrame(cases)
    else:
        print(f"Failed to get patients: {response.content}")

df
# cases
# Out:
#   archived_at                                            content  \
# 0        None  {'links': {'self': 'https://api.au4.cliniko.co...
# 1        None  {'links': {'self': 'https://api.au4.cliniko.co...
# 2        None  {'links': {'self': 'https://api.au4.cliniko.co...
#
#       content_type            created_at          description       filename  \
# 0  application/pdf  2025-02-06T00:34:12Z                 None  ED15_test.pdf
# 1  application/pdf  2025-02-06T02:49:19Z  testing file upload  ED15_test.pdf
# 2  application/pdf  2025-02-06T02:56:35Z  testing file upload  ED15_test.pdf
#
#                     id pinned_at          processed_at  processing_completed  \
# 0  1614817545364186273      None  2025-02-06T00:34:12Z                  True
# 1  1614885549754033908      None  2025-02-06T02:49:19Z                  True
# 2  1614889214292272938      None  2025-02-06T02:56:36Z                  True
#
#     size            updated_at  \
# 0  86988  2025-02-06T00:34:12Z
# 1  86988  2025-02-06T02:49:19Z
# 2  86988  2025-02-06T02:56:36Z
#
#                                              patient  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                                 user  \
# 0  {'links': {'self': 'https://api.au4.cliniko.co...
# 1  {'links': {'self': 'https://api.au4.cliniko.co...
# 2  {'links': {'self': 'https://api.au4.cliniko.co...
#
#                                                links
# 0  {'self': 'https://api.au4.cliniko.com/v1/patie...
# 1  {'self': 'https://api.au4.cliniko.com/v1/patie...
# 2  {'self': 'https://api.au4.cliniko.com/v1/patie...

# %%
int(df.get("id", None)[0])
# Out:
# 1614817545364186273

# %% [markdown]
# ### Send File

# %%
patient_id = 1599573992308483790

# %% [markdown]
# #### Get attachment link

# %%
with clinico_client() as client:
    response = UniversalClinikoAPI.sync_detailed(
        client=client,
        method="get",
        url=f"/patients/{patient_id}/attachment_presigned_post/",
    )
    if response.status_code == 200:
        file_attach = json.loads(response.content)
        # cases = parsed_content["patient_attachments"]
        # df = pd.DataFrame(cases)
        
    else:
        print(f"Failed to get patients: {response.content}")

# df
# cases
file_attach
# Out:
# {'fields': {'key': '1599555820796782568/patients/1599573992308483790/attachments/temp/674884ed-8430-45ae-9bb3-313a5bc92b61/${filename}',
#   'success_action_status': '201',
#   'acl': 'private',
#   'policy': '...',
#   'x-amz-credential': 'AKIA3ZVZHQSC5UQ6TNWX/20250206/ap-southeast-2/s3/aws4_request',
#   'x-amz-algorithm': 'AWS4-HMAC-SHA256',
#   'x-amz-date': '20250206T030858Z',
#   'x-amz-signature': 'e9291bf0629c35df28161577209ec6d00f9b4ade37d32740fc0297ec03328687'},
#  'url': 'https://cliniko-files-production-au4-ap-southeast-2.s3.ap-southeast-2.amazonaws.com'}

# %% [markdown]
# #### Actual file upload

# %%
import requests
import xml.etree.ElementTree as ET

url = file_attach['url']
fields = file_attach['fields']
file_name = "ED15_test.pdf"

files = {'file': (file_name, open(file_name, 'rb'))}

response = requests.post(url, data=fields, files=files)

if response.status_code == 201:
    # Parse XML Response
    upload_content = response.content.decode("utf-8")
    root = ET.fromstring(upload_content)
    
    # Extract Key and Location
    location = root.find("Location").text
    file_key = root.find("Key").text
    etag = root.find("ETag").text

    print("\n✅ **File Upload Successful!**")
    print(f"📂 File: {file_name}")
    print(f"🔗 Uploaded to: {location}")
    print(f"🔑 File Key: {file_key}")
    print(f"🔍 ETag: {etag}\n")
    
    # Next step: Use `file_key` to create an attachment record in Cliniko
else:
    print("\n❌ **File Upload Failed!**")
    print(f"🔴 Status Code: {response.status_code}")
    print(f"📝 Response: {response.text}\n")
# Out:
# ✅ **File Upload Successful!**
# 📂 File: ED15_test.pdf
# 🔗 Uploaded to: https://cliniko-files-production-au4-ap-southeast-2.s3.ap-southeast-2.amazonaws.com/1599555820796782568%2Fpatients%2F1599573992308483790%2Fattachments%2Ftemp%2F674884ed-8430-45ae-9bb3-313a5bc92b61%2FED15_test.pdf
# 🔑 File Key: 1599555820796782568/patients/1599573992308483790/attachments/temp/674884ed-8430-45ae-9bb3-313a5bc92b61/ED15_test.pdf
# 🔍 ETag: "ccd4b66f5da8560ceaefe3d73b7599e0"

# %% [markdown]
# #### Link uploaded file to patient

# %%
page=1
per_page=100
sort=[]
q = []
description = "final test, if this works, then we are good to go"

# %%
payload = {
  "patient_id": f"{patient_id}",
  "description": f"{description}",
  "upload_url": f"{file_attach['url']}/{file_key}",
}
# output_location = 
payload
# Out:
# {'patient_id': '1599573992308483790',
#  'description': 'final test, if this works, then we are good to go',
#  'upload_url': 'https://cliniko-files-production-au4-ap-southeast-2.s3.ap-southeast-2.amazonaws.com/1599555820796782568/patients/1599573992308483790/attachments/temp/674884ed-8430-45ae-9bb3-313a5bc92b61/ED15_test.pdf'}

# %%
with clinico_client() as client:
    response = UniversalClinikoAPI.sync_detailed(
        client=client,
        page=page,
        per_page=per_page,
        sort=sort,
        q=q,
        method="post",
        url="/patient_attachments",
        json=payload
    )
    if response.status_code == 201:
        parsed_content = json.loads(response.content)
    else:
        print(f"Failed to get patients: {response.content}")

parsed_content
# cases
# Out:
# {'archived_at': None,
#  'content': None,
#  'content_type': None,
#  'created_at': '2025-02-06T03:12:01Z',
#  'description': 'final test, if this works, then we are good to go',
#  'filename': None,
#  'id': '1614896980356507535',
#  'pinned_at': None,
#  'processed_at': None,
#  'processing_completed': False,
#  'size': None,
#  'updated_at': '2025-02-06T03:12:01Z',
#  'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599573992308483790'}},
#  'user': {'links': {'self': 'https://api.au4.cliniko.com/v1/users/1599555821232989634'}},
#  'links': {'self': 'https://api.au4.cliniko.com/v1/patient_attachments/1614896980356507535'}}

# %% [markdown]
# ## Direct Method

# %%
url = os.getenv("CLINIKO_URL")
key = os.getenv("CLINIKO_KEY")
vendor_name = os.getenv("CLINIKO_VENDOR_NAME")
vendor_email = os.getenv("CLINIKO_VENDOR_EMAIL")
key
# Out:
# 'MS0xNTk5NTU5NzM2ODY3NDMyMzE1LXVrMDZiVUIrQXhDVTRPbnpSdXJRYmlnRTh1YmhuVUhr-au4'

# %%
# !http -a $CLINIKO_KEY: https://api.au4.cliniko.com/v1/individual_appointments?q[]=cancelled_at:*  Accept:application/json User-Agent:"$CLINIKO_VENDOR_NAME ($CLINIKO_VENDOR_EMAIL)"
# Out:
# HTTP/1.1 200 OK
# Cache-Control: max-age=0, private, must-revalidate
# Cliniko-Account-Id: 1599555820796782568
# Cliniko-Patient-Ids: 1599573994523076304,1599573997425534674,1599573992308483790,1599574001686947542,1599573990169388748,1599573989104035531
# Cliniko-Patient-Ids-Count: 6
# Cliniko-User-Id: 1599555821232989634
# Connection: keep-alive
# Content-Encoding: gzip
# Content-Type: application/json; charset=utf-8
# Date: Tue, 21 Jan 2025 07:45:38 GMT
# ETag: "182329a90da72785deba030cfc25e33c"
# Referrer-Policy: strict-origin-when-cross-origin
# Strict-Transport-Security: max-age=31536000; includeSubDomains
# Transfer-Encoding: chunked
# Vary: Accept,Accept-Encoding
# Via: 1.1 9aa243cb9bbef2c2e1dda853705bfb92.cloudfront.net (CloudFront)
# X-Amz-Cf-Id: sjdtE4yDXSGorUFJOAafOvjjAp2akiOxQtHVaJiR4X_P-FjZ3FIuOA==
# X-Amz-Cf-Pop: BNE50-P1
# X-Cache: Miss from cloudfront
# X-Content-Type-Options: nosniff
# X-Download-Options: noopen
# X-Frame-Options: SAMEORIGIN
# X-Permitted-Cross-Domain-Policies: none
# X-Request-Id: 82956d5e3e0d2172bad408ade066367b
# X-Runtime: 0.040508
# X-XSS-Protection: 0
#
# {
#     "individual_appointments": [
#         {
#             "appointment_type": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109"
#                 }
#             },
#             "archived_at": null,
#             "attendees": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599575407709923219/attendees"
#                 }
#             },
#             "booking_ip_address": null,
#             "business": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/businesses/1599555824487770101"
#                 }
#             },
#             "cancellation_note": null,
#             "cancellation_reason": null,
#             "cancellation_reason_description": "",
#             "cancelled_at": null,
#             "conflicts": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599575407709923219/conflicts"
#                 }
#             },
#             "created_at": "2025-01-15T23:50:47Z",
#             "deleted_at": null,
#             "did_not_arrive": false,
#             "email_reminder_sent": false,
#             "ends_at": "2025-01-16T00:45:00Z",
#             "has_patient_appointment_notes": false,
#             "id": "1599575407709923219",
#             "invoice_status": null,
#             "links": {
#                 "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599575407709923219"
#             },
#             "notes": null,
#             "online_booking_policy_accepted": null,
#             "patient": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patients/1599573994523076304"
#                 }
#             },
#             "patient_arrived": false,
#             "patient_name": "David Barker",
#             "practitioner": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/practitioners/1599555821358819229"
#                 }
#             },
#             "repeat_rule": {},
#             "repeats": null,
#             "sms_reminder_sent": false,
#             "starts_at": "2025-01-16T00:00:00Z",
#             "telehealth_url": "https://rmetrics.au4.cliniko.com/appointments/1599575407709923219/connect",
#             "treatment_note_status": null,
#             "updated_at": "2025-01-15T23:50:48Z"
#         },
#         {
#             "appointment_type": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109"
#                 }
#             },
#             "archived_at": null,
#             "attendees": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599575758110468000/attendees"
#                 }
#             },
#             "booking_ip_address": null,
#             "business": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/businesses/1599555824487770101"
#                 }
#             },
#             "cancellation_note": null,
#             "cancellation_reason": null,
#             "cancellation_reason_description": "",
#             "cancelled_at": null,
#             "conflicts": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599575758110468000/conflicts"
#                 }
#             },
#             "created_at": "2025-01-15T23:51:29Z",
#             "deleted_at": null,
#             "did_not_arrive": false,
#             "email_reminder_sent": false,
#             "ends_at": "2025-01-17T02:45:00Z",
#             "has_patient_appointment_notes": false,
#             "id": "1599575758110468000",
#             "invoice_status": null,
#             "links": {
#                 "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599575758110468000"
#             },
#             "notes": "appointment notes",
#             "online_booking_policy_accepted": null,
#             "patient": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patients/1599573997425534674"
#                 }
#             },
#             "patient_arrived": false,
#             "patient_case": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patient_cases/1599575756776678510"
#                 }
#             },
#             "patient_name": "Michael Wagner",
#             "practitioner": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/practitioners/1599555821358819229"
#                 }
#             },
#             "repeat_rule": {},
#             "repeats": null,
#             "sms_reminder_sent": false,
#             "starts_at": "2025-01-17T02:00:00Z",
#             "telehealth_url": "https://rmetrics.au4.cliniko.com/appointments/1599575758110468000/connect",
#             "treatment_note_status": null,
#             "updated_at": "2025-01-15T23:51:29Z"
#         },
#         {
#             "appointment_type": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109"
#                 }
#             },
#             "archived_at": null,
#             "attendees": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576136872896479/attendees"
#                 }
#             },
#             "booking_ip_address": null,
#             "business": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/businesses/1599555824487770101"
#                 }
#             },
#             "cancellation_note": null,
#             "cancellation_reason": null,
#             "cancellation_reason_description": "",
#             "cancelled_at": null,
#             "conflicts": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576136872896479/conflicts"
#                 }
#             },
#             "created_at": "2025-01-15T23:52:14Z",
#             "deleted_at": null,
#             "did_not_arrive": false,
#             "email_reminder_sent": false,
#             "ends_at": "2025-01-20T00:45:00Z",
#             "has_patient_appointment_notes": false,
#             "id": "1599576136872896479",
#             "invoice_status": null,
#             "links": {
#                 "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576136872896479"
#             },
#             "notes": null,
#             "online_booking_policy_accepted": null,
#             "patient": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patients/1599573992308483790"
#                 }
#             },
#             "patient_arrived": false,
#             "patient_case": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patient_cases/1599576134842852464"
#                 }
#             },
#             "patient_name": "April Meyer",
#             "practitioner": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/practitioners/1599555821358819229"
#                 }
#             },
#             "repeat_rule": {},
#             "repeats": null,
#             "sms_reminder_sent": false,
#             "starts_at": "2025-01-20T00:00:00Z",
#             "telehealth_url": "https://rmetrics.au4.cliniko.com/appointments/1599576136872896479/connect",
#             "treatment_note_status": null,
#             "updated_at": "2025-01-15T23:52:14Z"
#         },
#         {
#             "appointment_type": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109"
#                 }
#             },
#             "archived_at": null,
#             "attendees": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576235816527842/attendees"
#                 }
#             },
#             "booking_ip_address": null,
#             "business": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/businesses/1599555824487770101"
#                 }
#             },
#             "cancellation_note": null,
#             "cancellation_reason": null,
#             "cancellation_reason_description": "",
#             "cancelled_at": null,
#             "conflicts": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576235816527842/conflicts"
#                 }
#             },
#             "created_at": "2025-01-15T23:52:26Z",
#             "deleted_at": null,
#             "did_not_arrive": false,
#             "email_reminder_sent": false,
#             "ends_at": "2025-01-21T01:45:00Z",
#             "has_patient_appointment_notes": false,
#             "id": "1599576235816527842",
#             "invoice_status": null,
#             "links": {
#                 "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576235816527842"
#             },
#             "notes": null,
#             "online_booking_policy_accepted": null,
#             "patient": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patients/1599574001686947542"
#                 }
#             },
#             "patient_arrived": false,
#             "patient_name": "Christopher Mitchell",
#             "practitioner": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/practitioners/1599570839030736801"
#                 }
#             },
#             "repeat_rule": {},
#             "repeats": null,
#             "sms_reminder_sent": false,
#             "starts_at": "2025-01-21T01:00:00Z",
#             "telehealth_url": "https://rmetrics.au4.cliniko.com/appointments/1599576235816527842/connect",
#             "treatment_note_status": null,
#             "updated_at": "2025-01-15T23:52:26Z"
#         },
#         {
#             "appointment_type": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109"
#                 }
#             },
#             "archived_at": null,
#             "attendees": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576400384239592/attendees"
#                 }
#             },
#             "booking_ip_address": null,
#             "business": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/businesses/1599555824487770101"
#                 }
#             },
#             "cancellation_note": null,
#             "cancellation_reason": null,
#             "cancellation_reason_description": "",
#             "cancelled_at": null,
#             "conflicts": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576400384239592/conflicts"
#                 }
#             },
#             "created_at": "2025-01-15T23:52:46Z",
#             "deleted_at": null,
#             "did_not_arrive": false,
#             "email_reminder_sent": false,
#             "ends_at": "2025-01-21T01:45:00Z",
#             "has_patient_appointment_notes": false,
#             "id": "1599576400384239592",
#             "invoice_status": null,
#             "links": {
#                 "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576400384239592"
#             },
#             "notes": null,
#             "online_booking_policy_accepted": null,
#             "patient": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patients/1599573990169388748"
#                 }
#             },
#             "patient_arrived": false,
#             "patient_name": "Judith Moran",
#             "practitioner": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/practitioners/1599570839030736801"
#                 }
#             },
#             "repeat_rule": {},
#             "repeats": null,
#             "sms_reminder_sent": false,
#             "starts_at": "2025-01-21T01:00:00Z",
#             "telehealth_url": "https://rmetrics.au4.cliniko.com/appointments/1599576400384239592/connect",
#             "treatment_note_status": null,
#             "updated_at": "2025-01-15T23:52:46Z"
#         },
#         {
#             "appointment_type": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109"
#                 }
#             },
#             "archived_at": null,
#             "attendees": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576630341150704/attendees"
#                 }
#             },
#             "booking_ip_address": null,
#             "business": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/businesses/1599555824487770101"
#                 }
#             },
#             "cancellation_note": null,
#             "cancellation_reason": null,
#             "cancellation_reason_description": "",
#             "cancelled_at": null,
#             "conflicts": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576630341150704/conflicts"
#                 }
#             },
#             "created_at": "2025-01-15T23:53:13Z",
#             "deleted_at": null,
#             "did_not_arrive": false,
#             "email_reminder_sent": false,
#             "ends_at": "2025-01-20T02:45:00Z",
#             "has_patient_appointment_notes": false,
#             "id": "1599576630341150704",
#             "invoice_status": null,
#             "links": {
#                 "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599576630341150704"
#             },
#             "notes": null,
#             "online_booking_policy_accepted": null,
#             "patient": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patients/1599573990169388748"
#                 }
#             },
#             "patient_arrived": false,
#             "patient_name": "Judith Moran",
#             "practitioner": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/practitioners/1599570839030736801"
#                 }
#             },
#             "repeat_rule": {},
#             "repeats": null,
#             "sms_reminder_sent": false,
#             "starts_at": "2025-01-20T02:00:00Z",
#             "telehealth_url": "https://rmetrics.au4.cliniko.com/appointments/1599576630341150704/connect",
#             "treatment_note_status": null,
#             "updated_at": "2025-01-15T23:53:13Z"
#         },
#         {
#             "appointment_type": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109"
#                 }
#             },
#             "archived_at": null,
#             "attendees": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599650127776065232/attendees"
#                 }
#             },
#             "booking_ip_address": null,
#             "business": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/businesses/1599555824487770101"
#                 }
#             },
#             "cancellation_note": null,
#             "cancellation_reason": null,
#             "cancellation_reason_description": "",
#             "cancelled_at": null,
#             "conflicts": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599650127776065232/conflicts"
#                 }
#             },
#             "created_at": "2025-01-16T02:19:15Z",
#             "deleted_at": null,
#             "did_not_arrive": false,
#             "email_reminder_sent": false,
#             "ends_at": "2025-01-16T03:45:00Z",
#             "has_patient_appointment_notes": false,
#             "id": "1599650127776065232",
#             "invoice_status": 10,
#             "links": {
#                 "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599650127776065232"
#             },
#             "notes": null,
#             "online_booking_policy_accepted": null,
#             "patient": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patients/1599573989104035531"
#                 }
#             },
#             "patient_arrived": false,
#             "patient_case": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patient_cases/1599639556703921319"
#                 }
#             },
#             "patient_name": "Andrea Ferguson",
#             "practitioner": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/practitioners/1599555821358819229"
#                 }
#             },
#             "repeat_rule": {},
#             "repeats": null,
#             "sms_reminder_sent": false,
#             "starts_at": "2025-01-16T03:00:00Z",
#             "telehealth_url": "https://rmetrics.au4.cliniko.com/appointments/1599650127776065232/connect",
#             "treatment_note_status": null,
#             "updated_at": "2025-01-16T02:21:40Z"
#         },
#         {
#             "appointment_type": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109"
#                 }
#             },
#             "archived_at": null,
#             "attendees": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599650688193799897/attendees"
#                 }
#             },
#             "booking_ip_address": null,
#             "business": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/businesses/1599555824487770101"
#                 }
#             },
#             "cancellation_note": null,
#             "cancellation_reason": null,
#             "cancellation_reason_description": "",
#             "cancelled_at": null,
#             "conflicts": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599650688193799897/conflicts"
#                 }
#             },
#             "created_at": "2025-01-16T02:20:22Z",
#             "deleted_at": null,
#             "did_not_arrive": false,
#             "email_reminder_sent": false,
#             "ends_at": "2025-01-17T03:45:00Z",
#             "has_patient_appointment_notes": false,
#             "id": "1599650688193799897",
#             "invoice_status": null,
#             "links": {
#                 "self": "https://api.au4.cliniko.com/v1/individual_appointments/1599650688193799897"
#             },
#             "notes": null,
#             "online_booking_policy_accepted": null,
#             "patient": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patients/1599573989104035531"
#                 }
#             },
#             "patient_arrived": false,
#             "patient_case": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/patient_cases/1599639556703921319"
#                 }
#             },
#             "patient_name": "Andrea Ferguson",
#             "practitioner": {
#                 "links": {
#                     "self": "https://api.au4.cliniko.com/v1/practitioners/1599570839030736801"
#                 }
#             },
#             "repeat_rule": {},
#             "repeats": null,
#             "sms_reminder_sent": false,
#             "starts_at": "2025-01-17T03:00:00Z",
#             "telehealth_url": "https://rmetrics.au4.cliniko.com/appointments/1599650688193799897/connect",
#             "treatment_note_status": null,
#             "updated_at": "2025-01-16T02:20:22Z"
#         }
#     ],
#     "links": {
#         "self": "https://api.au4.cliniko.com/v1/individual_appointments?page=1&q%5B%5D=cancelled_at%3A%2A"
#     },
#     "total_entries": 8
# }

# %%
with clinico_client() as client:
    response = client.get_httpx_client().get(
        url=f"{client._base_url}/individual_appointments",
        headers=client._headers,
    )
    if response.status_code != 200:
        logger.error(f"Failed to create clients: {response.content}")
    
    parsed_content = json.loads(response.content)
parsed_content
# Out:
# {'individual_appointments': [{'archived_at': None,
#    'booking_ip_address': None,
#    'cancellation_note': None,
#    'cancellation_reason': None,
#    'cancellation_reason_description': '',
#    'cancelled_at': None,
#    'conflicts': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599575407709923219/conflicts'}},
#    'created_at': '2025-01-15T23:50:47Z',
#    'deleted_at': None,
#    'did_not_arrive': False,
#    'email_reminder_sent': False,
#    'ends_at': '2025-01-16T00:45:00Z',
#    'has_patient_appointment_notes': False,
#    'id': '1599575407709923219',
#    'invoice_status': None,
#    'notes': None,
#    'online_booking_policy_accepted': None,
#    'patient_arrived': False,
#    'patient_name': 'David Barker',
#    'repeat_rule': {},
#    'repeats': None,
#    'sms_reminder_sent': False,
#    'starts_at': '2025-01-16T00:00:00Z',
#    'telehealth_url': 'https://rmetrics.au4.cliniko.com/appointments/1599575407709923219/connect',
#    'treatment_note_status': None,
#    'updated_at': '2025-01-15T23:50:48Z',
#    'appointment_type': {'links': {'self': 'https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109'}},
#    'business': {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}},
#    'practitioner': {'links': {'self': 'https://api.au4.cliniko.com/v1/practitioners/1599555821358819229'}},
#    'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599573994523076304'}},
#    'attendees': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599575407709923219/attendees'}},
#    'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599575407709923219'}},
#   {'archived_at': None,
#    'booking_ip_address': None,
#    'cancellation_note': None,
#    'cancellation_reason': None,
#    'cancellation_reason_description': '',
#    'cancelled_at': None,
#    'conflicts': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599575758110468000/conflicts'}},
#    'created_at': '2025-01-15T23:51:29Z',
#    'deleted_at': None,
#    'did_not_arrive': False,
#    'email_reminder_sent': False,
#    'ends_at': '2025-01-17T02:45:00Z',
#    'has_patient_appointment_notes': False,
#    'id': '1599575758110468000',
#    'invoice_status': None,
#    'notes': 'appointment notes',
#    'online_booking_policy_accepted': None,
#    'patient_arrived': False,
#    'patient_name': 'Michael Wagner',
#    'repeat_rule': {},
#    'repeats': None,
#    'sms_reminder_sent': False,
#    'starts_at': '2025-01-17T02:00:00Z',
#    'telehealth_url': 'https://rmetrics.au4.cliniko.com/appointments/1599575758110468000/connect',
#    'treatment_note_status': None,
#    'updated_at': '2025-01-15T23:51:29Z',
#    'appointment_type': {'links': {'self': 'https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109'}},
#    'business': {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}},
#    'practitioner': {'links': {'self': 'https://api.au4.cliniko.com/v1/practitioners/1599555821358819229'}},
#    'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599573997425534674'}},
#    'patient_case': {'links': {'self': 'https://api.au4.cliniko.com/v1/patient_cases/1599575756776678510'}},
#    'attendees': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599575758110468000/attendees'}},
#    'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599575758110468000'}},
#   {'archived_at': None,
#    'booking_ip_address': None,
#    'cancellation_note': None,
#    'cancellation_reason': None,
#    'cancellation_reason_description': '',
#    'cancelled_at': None,
#    'conflicts': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576136872896479/conflicts'}},
#    'created_at': '2025-01-15T23:52:14Z',
#    'deleted_at': None,
#    'did_not_arrive': False,
#    'email_reminder_sent': False,
#    'ends_at': '2025-01-20T00:45:00Z',
#    'has_patient_appointment_notes': False,
#    'id': '1599576136872896479',
#    'invoice_status': None,
#    'notes': None,
#    'online_booking_policy_accepted': None,
#    'patient_arrived': False,
#    'patient_name': 'April Meyer',
#    'repeat_rule': {},
#    'repeats': None,
#    'sms_reminder_sent': False,
#    'starts_at': '2025-01-20T00:00:00Z',
#    'telehealth_url': 'https://rmetrics.au4.cliniko.com/appointments/1599576136872896479/connect',
#    'treatment_note_status': None,
#    'updated_at': '2025-01-15T23:52:14Z',
#    'appointment_type': {'links': {'self': 'https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109'}},
#    'business': {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}},
#    'practitioner': {'links': {'self': 'https://api.au4.cliniko.com/v1/practitioners/1599555821358819229'}},
#    'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599573992308483790'}},
#    'patient_case': {'links': {'self': 'https://api.au4.cliniko.com/v1/patient_cases/1599576134842852464'}},
#    'attendees': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576136872896479/attendees'}},
#    'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576136872896479'}},
#   {'archived_at': None,
#    'booking_ip_address': None,
#    'cancellation_note': None,
#    'cancellation_reason': None,
#    'cancellation_reason_description': '',
#    'cancelled_at': None,
#    'conflicts': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576235816527842/conflicts'}},
#    'created_at': '2025-01-15T23:52:26Z',
#    'deleted_at': None,
#    'did_not_arrive': False,
#    'email_reminder_sent': False,
#    'ends_at': '2025-01-21T01:45:00Z',
#    'has_patient_appointment_notes': False,
#    'id': '1599576235816527842',
#    'invoice_status': None,
#    'notes': None,
#    'online_booking_policy_accepted': None,
#    'patient_arrived': False,
#    'patient_name': 'Christopher Mitchell',
#    'repeat_rule': {},
#    'repeats': None,
#    'sms_reminder_sent': False,
#    'starts_at': '2025-01-21T01:00:00Z',
#    'telehealth_url': 'https://rmetrics.au4.cliniko.com/appointments/1599576235816527842/connect',
#    'treatment_note_status': None,
#    'updated_at': '2025-01-15T23:52:26Z',
#    'appointment_type': {'links': {'self': 'https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109'}},
#    'business': {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}},
#    'practitioner': {'links': {'self': 'https://api.au4.cliniko.com/v1/practitioners/1599570839030736801'}},
#    'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599574001686947542'}},
#    'attendees': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576235816527842/attendees'}},
#    'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576235816527842'}},
#   {'archived_at': None,
#    'booking_ip_address': None,
#    'cancellation_note': None,
#    'cancellation_reason': None,
#    'cancellation_reason_description': '',
#    'cancelled_at': None,
#    'conflicts': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576400384239592/conflicts'}},
#    'created_at': '2025-01-15T23:52:46Z',
#    'deleted_at': None,
#    'did_not_arrive': False,
#    'email_reminder_sent': False,
#    'ends_at': '2025-01-21T01:45:00Z',
#    'has_patient_appointment_notes': False,
#    'id': '1599576400384239592',
#    'invoice_status': None,
#    'notes': None,
#    'online_booking_policy_accepted': None,
#    'patient_arrived': False,
#    'patient_name': 'Judith Moran',
#    'repeat_rule': {},
#    'repeats': None,
#    'sms_reminder_sent': False,
#    'starts_at': '2025-01-21T01:00:00Z',
#    'telehealth_url': 'https://rmetrics.au4.cliniko.com/appointments/1599576400384239592/connect',
#    'treatment_note_status': None,
#    'updated_at': '2025-01-15T23:52:46Z',
#    'appointment_type': {'links': {'self': 'https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109'}},
#    'business': {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}},
#    'practitioner': {'links': {'self': 'https://api.au4.cliniko.com/v1/practitioners/1599570839030736801'}},
#    'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599573990169388748'}},
#    'attendees': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576400384239592/attendees'}},
#    'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576400384239592'}},
#   {'archived_at': None,
#    'booking_ip_address': None,
#    'cancellation_note': None,
#    'cancellation_reason': None,
#    'cancellation_reason_description': '',
#    'cancelled_at': None,
#    'conflicts': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576630341150704/conflicts'}},
#    'created_at': '2025-01-15T23:53:13Z',
#    'deleted_at': None,
#    'did_not_arrive': False,
#    'email_reminder_sent': False,
#    'ends_at': '2025-01-20T02:45:00Z',
#    'has_patient_appointment_notes': False,
#    'id': '1599576630341150704',
#    'invoice_status': None,
#    'notes': None,
#    'online_booking_policy_accepted': None,
#    'patient_arrived': False,
#    'patient_name': 'Judith Moran',
#    'repeat_rule': {},
#    'repeats': None,
#    'sms_reminder_sent': False,
#    'starts_at': '2025-01-20T02:00:00Z',
#    'telehealth_url': 'https://rmetrics.au4.cliniko.com/appointments/1599576630341150704/connect',
#    'treatment_note_status': None,
#    'updated_at': '2025-01-15T23:53:13Z',
#    'appointment_type': {'links': {'self': 'https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109'}},
#    'business': {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}},
#    'practitioner': {'links': {'self': 'https://api.au4.cliniko.com/v1/practitioners/1599570839030736801'}},
#    'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599573990169388748'}},
#    'attendees': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576630341150704/attendees'}},
#    'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599576630341150704'}},
#   {'archived_at': None,
#    'booking_ip_address': None,
#    'cancellation_note': None,
#    'cancellation_reason': None,
#    'cancellation_reason_description': '',
#    'cancelled_at': None,
#    'conflicts': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599650127776065232/conflicts'}},
#    'created_at': '2025-01-16T02:19:15Z',
#    'deleted_at': None,
#    'did_not_arrive': False,
#    'email_reminder_sent': False,
#    'ends_at': '2025-01-16T03:45:00Z',
#    'has_patient_appointment_notes': False,
#    'id': '1599650127776065232',
#    'invoice_status': 10,
#    'notes': None,
#    'online_booking_policy_accepted': None,
#    'patient_arrived': False,
#    'patient_name': 'Andrea Ferguson',
#    'repeat_rule': {},
#    'repeats': None,
#    'sms_reminder_sent': False,
#    'starts_at': '2025-01-16T03:00:00Z',
#    'telehealth_url': 'https://rmetrics.au4.cliniko.com/appointments/1599650127776065232/connect',
#    'treatment_note_status': None,
#    'updated_at': '2025-01-16T02:21:40Z',
#    'appointment_type': {'links': {'self': 'https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109'}},
#    'business': {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}},
#    'practitioner': {'links': {'self': 'https://api.au4.cliniko.com/v1/practitioners/1599555821358819229'}},
#    'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599573989104035531'}},
#    'patient_case': {'links': {'self': 'https://api.au4.cliniko.com/v1/patient_cases/1599639556703921319'}},
#    'attendees': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599650127776065232/attendees'}},
#    'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599650127776065232'}},
#   {'archived_at': None,
#    'booking_ip_address': None,
#    'cancellation_note': None,
#    'cancellation_reason': None,
#    'cancellation_reason_description': '',
#    'cancelled_at': None,
#    'conflicts': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599650688193799897/conflicts'}},
#    'created_at': '2025-01-16T02:20:22Z',
#    'deleted_at': None,
#    'did_not_arrive': False,
#    'email_reminder_sent': False,
#    'ends_at': '2025-01-17T03:45:00Z',
#    'has_patient_appointment_notes': False,
#    'id': '1599650688193799897',
#    'invoice_status': None,
#    'notes': None,
#    'online_booking_policy_accepted': None,
#    'patient_arrived': False,
#    'patient_name': 'Andrea Ferguson',
#    'repeat_rule': {},
#    'repeats': None,
#    'sms_reminder_sent': False,
#    'starts_at': '2025-01-17T03:00:00Z',
#    'telehealth_url': 'https://rmetrics.au4.cliniko.com/appointments/1599650688193799897/connect',
#    'treatment_note_status': None,
#    'updated_at': '2025-01-16T02:20:22Z',
#    'appointment_type': {'links': {'self': 'https://api.au4.cliniko.com/v1/appointment_types/1599555824135448109'}},
#    'business': {'links': {'self': 'https://api.au4.cliniko.com/v1/businesses/1599555824487770101'}},
#    'practitioner': {'links': {'self': 'https://api.au4.cliniko.com/v1/practitioners/1599570839030736801'}},
#    'patient': {'links': {'self': 'https://api.au4.cliniko.com/v1/patients/1599573989104035531'}},
#    'patient_case': {'links': {'self': 'https://api.au4.cliniko.com/v1/patient_cases/1599639556703921319'}},
#    'attendees': {'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599650688193799897/attendees'}},
#    'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments/1599650688193799897'}}],
#  'total_entries': 8,
#  'links': {'self': 'https://api.au4.cliniko.com/v1/individual_appointments?page=1'}}
