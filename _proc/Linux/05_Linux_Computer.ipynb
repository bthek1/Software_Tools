# %% [raw]
# ---
# description: New Ubuntu Computer
# output-file: linux_computer.html
# skip_exec: true
# skip_showdoc: true
# title: Linux Computer
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Install Git

# %% [markdown]
# ```sh
# sudo apt install git
# ```

# %% [markdown]
# ## Install Code

# %% [markdown]
# ```sh
# sudo snap install code --classic
#
# ```

# %% [markdown]
# ## Install stow

# %% [markdown]
# ```sh
# sudp apt install stow
# ```

# %% [markdown]
# ## Install tmux

# %% [markdown]
# ```sh
# sudo apt install tmux
# ```

# %% [markdown]
# ## [Set up ssh with Github](https://bthek1.github.io/WEB_doc/github.html)

# %% [markdown]
# ## Install curl

# %% [markdown]
# ```sh
# sudo apt install curl
#
# ```

# %% [markdown]
# ## Battery limit Change

# %% [markdown]
# ### Installation

# %% [markdown]
# ```sh
# sudo apt-get update
# sudo apt-get install tlp tlp-rdw
#
# ```

# %% [markdown]
# ### Enable

# %% [markdown]
# ```sh
# sudo systemctl enable tlp
#
# ```

# %% [markdown]
# ### Check

# %% [markdown]
# ```sh
#
# sudo systemctl status tlp
#
# sudo tlp-stat -b
#
# ```

# %% [markdown]
# ### Configure

# %% [markdown]
# > edit `/etc/tlp.conf`
# ```sh
# START_CHARGE_THRESH_BAT0=75
# STOP_CHARGE_THRESH_BAT0=80
#
# ```

# %% [markdown]
# ## Temporary Full Charge

# %% [markdown]
# ```sh
# sudo tlp fullcharge
# ```
